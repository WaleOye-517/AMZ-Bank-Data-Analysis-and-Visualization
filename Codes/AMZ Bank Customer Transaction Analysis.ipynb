# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('C:\Users\hp\Desktop\Data Science\Project 1\ANZ synthesised transaction dataset.xlsx',
                 'tran',index_col =None,na_values=['NA'])

# %%
df
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# 5          posted                NaN              NaN  ACC-1608363396
# 6      authorized                1.0              NaN  ACC-2776252858
# 7      authorized                1.0              NaN  ACC-2776252858
# 8      authorized                1.0              NaN   ACC-182446574
# 9          posted                NaN              NaN   ACC-602667573
# 10         posted                NaN              NaN  ACC-2171593283
# 11         posted                NaN              NaN  ACC-2776252858
# ...

# %%
dk=df.copy()

# %%
dk
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# 5          posted                NaN              NaN  ACC-1608363396
# 6      authorized                1.0              NaN  ACC-2776252858
# 7      authorized                1.0              NaN  ACC-2776252858
# 8      authorized                1.0              NaN   ACC-182446574
# 9          posted                NaN              NaN   ACC-602667573
# 10         posted                NaN              NaN  ACC-2171593283
# 11         posted                NaN              NaN  ACC-2776252858
# ...

# %%
dk.count()
# Out:
# status               12043
# card_present_flag     7717
# bpay_biller_code       885
# account              12043
# currency             12043
# long_lat             12043
# txn_description      12043
# merchant_id           7717
# merchant_code          883
# first_name           12043
# balance              12043
# date                 12043
# gender               12043
# age                  12043
# merchant_suburb       7717
# merchant_state        7717
# extraction           12043
# amount               12043
# transaction_id       12043
# country              12043
# customer_id          12043
# merchant_long_lat     7717
# movement             12043
# dtype: int64

# %%
oya_now=dk['merchant_code']

# %%
dk['long_lat'].isnull().values.all()
# Out:
# False

# %%
df.notnull().sum()
# Out:
# status               12043
# card_present_flag     7717
# bpay_biller_code       885
# account              12043
# currency             12043
# long_lat             12043
# txn_description      12043
# merchant_id           7717
# merchant_code          883
# first_name           12043
# balance              12043
# date                 12043
# gender               12043
# age                  12043
# merchant_suburb       7717
# merchant_state        7717
# extraction           12043
# amount               12043
# transaction_id       12043
# country              12043
# customer_id          12043
# merchant_long_lat     7717
# movement             12043
# dtype: int64

# %%
dk.first_name.nunique()
# Out:
# 80

# %%
df.isna().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %%
dk.customer_id.nunique()
# Out:
# 100

# %%
dk
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# 5          posted                NaN              NaN  ACC-1608363396
# 6      authorized                1.0              NaN  ACC-2776252858
# 7      authorized                1.0              NaN  ACC-2776252858
# 8      authorized                1.0              NaN   ACC-182446574
# 9          posted                NaN              NaN   ACC-602667573
# 10         posted                NaN              NaN  ACC-2171593283
# 11         posted                NaN              NaN  ACC-2776252858
# ...

# %%
dk.isna().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %%
dk.drop(['bpay_biller_code','merchant_id','merchant_code','merchant_suburb',
        'merchant_state','merchant_long_lat','card_present_flag'],axis=1,inplace=True)

# %%
dk.isna().sum()
# Out:
# status             0
# account            0
# currency           0
# long_lat           0
# txn_description    0
# first_name         0
# balance            0
# date               0
# gender             0
# age                0
# extraction         0
# amount             0
# transaction_id     0
# country            0
# customer_id        0
# movement           0
# dtype: int64

# %%
ud=dk.first_name.unique()
print ud
# Out:
# [u'Diana' u'Michael' u'Rhonda' u'Robert' u'Kristin' u'Tonya' u'Fernando'
#  u'Isaiah' u'Ricky' u'Jeffrey' u'Patrick' u'Karen' u'Ruth' u'Kimberly'
#  u'Joseph' u'Tiffany' u'Emily' u'Christine' u'Ryan' u'Michelle' u'Richard'
#  u'Jessica' u'Ronald' u'Kaitlyn' u'Lori' u'Virginia' u'Andrew' u'Susan'
#  u'Luis' u'Gregory' u'Barry' u'Daniel' u'Renee' u'Amy' u'Christopher'
#  u'Marissa' u'Eric' u'Natasha' u'Edward' u'Craig' u'Sandra' u'Debra'
#  u'Michele' u'Antonio' u'Tyler' u'Lucas' u'Jonathan' u'Matthew' u'James'
#  u'Mackenzie' u'Linda' u'Dustin' u'Heather' u'Derek' u'Scott' u'Charles'
#  u'Tim' u'Melissa' u'Darren' u'Jacqueline' u'Cindy' u'Stephanie'
#  u'Rachael' u'Mary' u'Maria' u'Timothy' u'Nathaniel' u'Elizabeth' u'Paul'
#  u'Sarah' u'Alexander' u'Donald' u'Kenneth' u'Ashley' u'Catherine'
#  u'Billy' u'Abigail' u'Brian' u'David' u'Robin']

# %%
jy = dk.account.nunique()
print jy
# Out:
# 100

# %%
dm=dk.groupby('first_name').count()
print dm
# Out:
#              status  account  currency  long_lat  txn_description  balance  \
# first_name
# Abigail         102      102       102       102              102      102
# Alexander        91       91        91        91               91       91
# Amy             124      124       124       124              124      124
# Andrew           34       34        34        34               34       34
# Antonio         115      115       115       115              115      115
# Ashley           75       75        75        75               75       75
# Barry           122      122       122       122              122      122
# Billy            77       77        77        77               77       77
# Brian            63       63        63        63               63       63
# Catherine        62       62        62        62               62       62
# Charles         145      145       145       145              145      145
# ...

# %%
dm

# %%
dk
# Out:
#            status         account currency       long_lat txn_description  \
# 0      authorized  ACC-1598451071      AUD  153.41 -27.95             POS
# 1      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 2      authorized  ACC-1222300524      AUD  151.23 -33.94             POS
# 3      authorized  ACC-1037050564      AUD  153.10 -27.66       SALES-POS
# 4      authorized  ACC-1598451071      AUD  153.41 -27.95       SALES-POS
# 5          posted  ACC-1608363396      AUD  151.22 -33.87         PAYMENT
# 6      authorized  ACC-2776252858      AUD  144.95 -37.76       SALES-POS
# 7      authorized  ACC-2776252858      AUD  144.95 -37.76             POS
# 8      authorized   ACC-182446574      AUD  116.06 -32.00             POS
# 9          posted   ACC-602667573      AUD  151.23 -33.96      INTER BANK
# 10         posted  ACC-2171593283      AUD  146.94 -36.04         PAYMENT
# 11         posted  ACC-2776252858      AUD  144.95 -37.76         PAYMENT
# ...

# %%
dk.amount.mean()
# Out:
# 187.93358797641767

# %%
dk[dk['amount'].isin([8835.98])]
# Out:
#        status         account currency       long_lat txn_description  \
# 2401   posted  ACC-1523339231      AUD  115.83 -31.90      PAY/SALARY
# 6529   posted  ACC-1523339231      AUD  115.83 -31.90      PAY/SALARY
# 10429  posted  ACC-1523339231      AUD  115.83 -31.90      PAY/SALARY
# 10430  posted  ACC-1523339231      AUD  115.83 -31.90      PAY/SALARY
#
#       first_name   balance       date gender  age  \
# 2401         Tim  62647.22 2018-08-20      M   40
# 6529         Tim  70242.78 2018-09-20      M   40
# 10429        Tim  77054.31 2018-10-19      M   40
# 10430        Tim  85890.29 2018-10-19      M   40
#
#                          extraction   amount  \
# 2401   2018-08-20T13:00:00.000+0000  8835.98
# 6529   2018-09-20T13:00:00.000+0000  8835.98
# 10429  2018-10-19T13:00:00.000+0000  8835.98
# 10430  2018-10-19T13:00:00.000+0000  8835.98
#
#                          transaction_id    country     customer_id movement
# ...

# %%
aug = de.amount.loc['2018-08-01T00:00:00.000+0000':'2018-09-01T00:00:00.000+0000'].count()
print aug
# Out:
# 3943

# %%
sep = de.amount.loc['2018-09-01T00:00:00.000+0000':'2018-10-01T00:00:00.000+0000'].count()
print sep
# Out:
# 4013

# %%
oct = de.amount.loc['2018-10-01T00:00:00.000+0000':'2018-11-01T00:00:00.000+0000'].count()
print oct
# Out:
# 4087

# %%
average_transaction_monthly = (aug+sep+oct)/3
print average_transaction_monthly
# Out:
# 4014

# %%
dk.amount.describe()
# Out:
# count    12043.000000
# mean       187.933588
# std        592.599934
# min          0.100000
# 25%         16.000000
# 50%         29.000000
# 75%         53.655000
# max       8835.980000
# Name: amount, dtype: float64

# %%
de = dk.set_index(['extraction'])

# %%
de
# Out:
#                                   status         account currency  \
# extraction
# 2018-08-01T01:01:15.000+0000  authorized  ACC-1598451071      AUD
# 2018-08-01T01:13:45.000+0000  authorized  ACC-1598451071      AUD
# 2018-08-01T01:26:15.000+0000  authorized  ACC-1222300524      AUD
# 2018-08-01T01:38:45.000+0000  authorized  ACC-1037050564      AUD
# 2018-08-01T01:51:15.000+0000  authorized  ACC-1598451071      AUD
# 2018-08-01T02:00:00.000+0000      posted  ACC-1608363396      AUD
# 2018-08-01T02:23:04.000+0000  authorized  ACC-2776252858      AUD
# 2018-08-01T04:11:25.000+0000  authorized  ACC-2776252858      AUD
# 2018-08-01T04:40:00.000+0000  authorized   ACC-182446574      AUD
# 2018-08-01T06:00:00.000+0000      posted   ACC-602667573      AUD
# 2018-08-01T06:00:00.000+0000      posted  ACC-2171593283      AUD
# 2018-08-01T06:00:00.000+0000      posted  ACC-2776252858      AUD
# 2018-08-01T06:06:40.000+0000  authorized   ACC-182446574      AUD
# ...

# %%
average_day_volume=de.amount.loc['2018-08-01T00:00:00.000+0000':'2018-08-02T00:00:00.000+0000'].count()
print "{:,} Transactions".format(average_day_volume)
# Out:
# 137 Transactions

# %%
average_day_total=de.amount.loc['2018-08-01T00:00:00.000+0000':'2018-08-02T00:00:00.000+0000'].sum()
print  "{:,} AUD".format(average_day_total)
# Out:
# 29,867.94 AUD

# %%
average_day_analysis=de.amount.loc['2018-08-01T00:00:00.000+0000':'2018-08-02T00:00:00.000+0000'].describe()
print average_day_analysis
# Out:
# count     137.000000
# mean      218.014161
# std       636.852734
# min         3.250000
# 25%        15.610000
# 50%        27.820000
# 75%        50.000000
# max      3903.950000
# Name: amount, dtype: float64

# %%
average_week_volume=de.amount.loc['2018-10-01T00:00:00.000+0000':'2018-10-08T00:00:00.000+0000'].count()
print  "{:,} Transactions".format(average_week_volume)
# Out:
# 949 Transactions

# %%
average_week_total=de.amount.loc['2018-10-01T00:00:00.000+0000':'2018-10-08T00:00:00.000+0000'].sum()
print  "{:,} AUD".format(average_week_total)
# Out:
# 169,876.63 AUD

# %%
average_week_analysis = de.amount.loc['2018-10-01T00:00:00.000+0000':'2018-10-08T00:00:00.000+0000'].describe()
print average_week_analysis
# Out:
# count     949.000000
# mean      179.005933
# std       552.306216
# min         0.100000
# 25%        16.540000
# 50%        29.000000
# 75%        54.590000
# max      4405.300000
# Name: amount, dtype: float64

# %%
average_month_volume = de.amount.loc['2018-09-01T00:00:00.000+0000':'2018-10-01T00:00:00.000+0000'].count()
print  "{:,} Transactions".format(average_month_volume)
# Out:
# 4,013 Transactions

# %%
average_month_total = de.amount.loc['2018-09-01T00:00:00.000+0000':'2018-10-01T00:00:00.000+0000'].sum()
print "{:,} AUD".format(average_month_total)
# Out:
# 730,550.21 AUD

# %%
average_month_analysis = de.amount.loc['2018-09-01T00:00:00.000+0000':'2018-10-01T00:00:00.000+0000'].describe()
print average_month_analysis
# Out:
# count    4013.000000
# mean      182.045903
# std       574.694422
# min         0.100000
# 25%        16.090000
# 50%        29.000000
# 75%        54.400000
# max      8835.980000
# Name: amount, dtype: float64

# %%
ANZ_volume = de.amount.count()
print "{:,} Transactions".format(ANZ_volume)
# Out:
# 12,043 Transactions

# %%
ANZ_total = de.amount.sum()
print "{:,} AUD".format(ANZ_total)
# Out:
# 2,263,284.2 AUD

# %%
ANZ_analysis = de.amount.describe()
print ANZ_analysis
# Out:
# count    12043.000000
# mean       187.933588
# std        592.599934
# min          0.100000
# 25%         16.000000
# 50%         29.000000
# 75%         53.655000
# max       8835.980000
# Name: amount, dtype: float64

# %%
q3 = dk.amount.quantile(.75)
print q3
# Out:
# 53.655

# %%
q1=dk.amount.quantile(.25)
print q1
# Out:
# 16.0

# %%
low_outliers = q1 - (1.5*iqr)
print low_outliers
# Out:
# -40.4825

# %%
high_outliers = q3 + (1.5*iqr)
print high_outliers
# Out:
# 110.1375

# %%
outliers=dk[dk['amount']>110.1375]

# %%
outliers_volume=outliers.amount.count()
print "{:,} Transactions".format(outliers_volume)
# Out:
# 1,844 Transactions

# %%
real_data=dk[dk['amount']<100.1375]

# %%
real_data_volume=real_data.amount.count()
print "{:,} Transactions".format(real_data_volume)
# Out:
# 10,101 Transactions

# %%
real_data_amount = real_data.amount.sum()
print "{:,} AUD".format(real_data_amount)
# Out:
# 289,269.97 AUD

# %%
outlier_total_amount = outliers.amount.sum()
print "{:,} AUD".format(outlier_total_amount)
# Out:
# 1,963,677.29 AUD

# %%
real_data_analysis = real_data.amount.describe()
print real_data_analysis
# Out:
# count    10101.000000
# mean        28.637756
# std         19.152384
# min          0.100000
# 25%         14.240000
# 50%         24.000000
# 75%         38.820000
# max        100.060000
# Name: amount, dtype: float64

# %%
outliers_analysis=outliers.amount.describe()
print outliers_analysis
# Out:
# count    1844.000000
# mean     1064.900916
# std      1176.268949
# min       110.180000
# 25%       163.000000
# 50%       725.320000
# 75%      1626.480000
# max      8835.980000
# Name: amount, dtype: float64

# %%
percentage_of_outliers_volume = (outliers_volume / ANZ_volume)*100
print "{} %".format(percentage_of_outliers_volume)
# Out:
# 15.3117993855 %

# %%
from __future__ import division

# %%
100-percentage_of_outliers_volume
# Out:
# 84.68820061446483

# %%
percentage_of_outliers_amount = (outlier_total_amount / ANZ_total)*100
print "{} %".format(percentage_of_outliers_amount)
# Out:
# 86.7622939267 %

# %%
outlierss=dk[dk['amount']>1000]

# %%
outlierss.account.nunique()
# Out:
# 91

# %%
iqr = q3 - q1
print iqr
# Out:
# 37.655
